# %%
# Licensed under the MIT License.
import scipy.io as sio
import read_files
import matplotlib.pyplot as plt

# %%
out_path='outputs/sub-0001_predmask.mat'
pred_mask=sio.loadmat(out_path)['pred_mask']

# %%
plt.imshow(read_files.MIP(pred_mask,axisNum=1))

# %%
plot_MIPs(patient_sub,binary_mask,DATA_FOLDER,axisNum=1)

# %%
DATA_FOLDER
# Out:
# '../data/mat2D/'
